# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install moviepy

# %%
from moviepy.editor import *
audioclip = AudioFileClip("mlk.wav")
audioclip.subclip(12,22).write_audiofile('content/chmlk.wav')
# Out:
# [MoviePy] Writing audio in content/chmlk.wav
#   0%|          | 0/221 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/moviepy/audio/io/ffmpeg_audiowriter.py in write_frames(self, frames_array)
#      75             try:
# ---> 76                 self.proc.stdin.write(frames_array.tobytes())
#      77             except NameError:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-6fb6a377d63b> in <module>()
#       1 from moviepy.editor import *
#       2 audioclip = AudioFileClip("mlk.wav")
# ----> 3 audioclip.subclip(12,22).write_audiofile('content/chmlk.wav')
#
# ...

# %%
import os
print(os.listdir('/content/drive/My Drive/AudioFiles'))
# Out:
# ['Ajay.wav']
